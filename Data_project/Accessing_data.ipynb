# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
# Get the first row
df.iloc[0]
# Out:
# job_title_short                                       Senior Data Engineer
# job_title                Senior Clinical Data Engineer / Principal Clin...
# job_location                                                 Watertown, CT
# job_via                                                    via Work Nearby
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                       Texas, United States
# job_posted_date                                        2023-06-16 13:44:15
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                  United States
# salary_rate                                                           None
# ...

# %%
# Get the thrid element
df.iloc[2]
# Out:
# job_title_short                                              Data Engineer
# job_title                Data Engineer/Scientist/Analyst, Mid or Senior...
# job_location                                               Berlin, Germany
# job_via                                                       via LinkedIn
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                    Germany
# job_posted_date                                        2023-10-10 13:14:55
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                        Germany
# salary_rate                                                           None
# ...

# %%
# Get the job_skills (index 15) and job_type_skills (index 16) for the third and fourth rows

df.iloc[[2,3],[15,16]]
# Out:
#                                           job_skills  \
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
#
#                                      job_type_skills
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...

# %%
# Get the first 10 rows of data
df.iloc[:9]
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
#
#                    job_location             job_via         job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby                 Full-time
# ...

# %%
# Get the first five columns of the DataFrame and all of the rows.
df.iloc[:,:5]
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
# Getting top 10 rows for job_skills and job_type_skills using loc
df.loc[:9,['job_skills','job_type_skills']]
# Out:
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
# 5                           ['python', 'sql', 'gcp']
# 6  ['sql', 'python', 'java', 'sql server', 'gcp',...
# 7  ['sql', 'nosql', 'gcp', 'azure', 'aws', 'bigqu...
# 8                ['excel', 'powerpoint', 'power bi']
# 9  ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# 5  {'cloud': ['gcp'], 'programming': ['python', '...
# ...

# %%
df.loc[:10,['salary_year_avg','salary_hour_avg']]
# Out:
#     salary_year_avg  salary_hour_avg
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6               NaN              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN

# %%
median_year_avg = df['salary_year_avg'].median()

median_year_avg
# Out:
# 115000.0

# %%
median_hour_avg = df['salary_hour_avg'].median()

median_hour_avg
# Out:
# 45.97999954223633

# %%
df_cleaned = df

# %%
df_cleaned['salary_year_avg'] = df_cleaned['salary_year_avg'].fillna(median_year_avg)

# %%
df_cleaned['salary_hour_avg'] = df_cleaned['salary_hour_avg'].fillna(median_hour_avg)

# %%
df_cleaned.loc[:10,['salary_year_avg','salary_hour_avg']]
# Out:
#     salary_year_avg  salary_hour_avg
# 0          115000.0            45.98
# 1          115000.0            45.98
# 2          115000.0            45.98
# 3          115000.0            45.98
# 4          115000.0            45.98
# 5          115000.0            45.98
# 6          115000.0            45.98
# 7          115000.0            45.98
# 8          115000.0            45.98
# 9          115000.0            45.98
# 10         115000.0            45.98

# %%
df_cleaned
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df_unique = df_cleaned

# %%
df_unique = df_unique.drop_duplicates()

# %%
df_unique = df_unique.drop_duplicates(subset=['job_title','company_name'])

# %%
print(len(df_cleaned)-len(df_unique))
# Out:
# 277699

# %%
df_unique.sample(n=5,random_state=42)
# Out:
#               job_title_short  \
# 213738  Senior Data Scientist
# 356513   Senior Data Engineer
# 581679           Data Analyst
# 649012          Data Engineer
# 171348           Data Analyst
#
#                                               job_title  \
# 213738                             Data Management Lead
# 356513  Senior Lead Data Engineer - Energetic Workplace
# 581679                  Technical Data Analyst (Remote)
# 649012                         Junior SQL Data Engineer
# 171348                    Data Analyst Marketing Intern
#
#                                  job_location          job_via  \
# 213738      Taguig, Metro Manila, Philippines  via Trabajo.org
# 356513  São Paulo, State of São Paulo, Brazil     via GrabJobs
# 581679                               Anywhere     via LinkedIn
# 649012                             London, UK    via WJHL Jobs
# 171348                          Paris, France        via BeBee
#
# ...

# %%
df.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst             115000.0
# Cloud Engineer               115000.0
# Data Analyst                 115000.0
# Data Engineer                115000.0
# Data Scientist               115000.0
# Machine Learning Engineer    115000.0
# Senior Data Analyst          115000.0
# Senior Data Engineer         115000.0
# Senior Data Scientist        115000.0
# Software Engineer            115000.0
# Name: salary_year_avg, dtype: float64

# %%
df.pivot_table(values='salary_year_avg',index='job_title_short',aggfunc='median')
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst                  115000.0
# Cloud Engineer                    115000.0
# Data Analyst                      115000.0
# Data Engineer                     115000.0
# Data Scientist                    115000.0
# Machine Learning Engineer         115000.0
# Senior Data Analyst               115000.0
# Senior Data Engineer              115000.0
# Senior Data Scientist             115000.0
# Software Engineer                 115000.0

# %%
df_job_country_salary = df.pivot_table(
    values='salary_year_avg',        # The data to aggregate
    index='job_country',             # Rows (index of pivot table)
    columns='job_title_short',       # Columns (pivot table headers)
    aggfunc='median'                 # Aggregation function
)

df_job_country_salary
# Out:
# job_title_short  Business Analyst  Cloud Engineer  Data Analyst  \
# job_country
# Afghanistan              115000.0             NaN      115000.0
# Albania                  115000.0        115000.0      115000.0
# Algeria                  115000.0        115000.0      115000.0
# Angola                   115000.0             NaN      115000.0
# Argentina                115000.0        115000.0      115000.0
# ...                           ...             ...           ...
# Venezuela                115000.0        115000.0      115000.0
# Vietnam                  115000.0        115000.0      115000.0
# Yemen                    115000.0             NaN      115000.0
# Zambia                   115000.0        115000.0      115000.0
# Zimbabwe                 115000.0        115000.0      115000.0
#
# job_title_short  Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_country
# Afghanistan                NaN        115000.0                        NaN
# ...

# %%
# filter df_job_country_salary for top 6 countries
top_countries = df['job_country'].value_counts().head(6).index
df_job_country_salary = df_job_country_salary.loc[top_countries]

# filter df_job_country_salary for list of 6 job titles
job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist'] # 'Senior Data Analyst', 'Senior Data Engineer', 'Senior Data Scientist']
df_job_country_salary = df_job_country_salary[job_titles]

df_job_country_salary.plot(kind='bar')
plt.ylabel('Median Salary ($USD)')
plt.xlabel('')
plt.title('Median Salary by Country and Job Title')
plt.xticks(rotation=45, ha='right')
plt.show()
